# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define softer colors
approve_color = '#2F4F4F'  # Light green
disapprove_color = '#696969'  # Light red

# Bar Chart (Side-by-Side Bars)
plt.figure(figsize=(10, 6))
bar_width = 0.35
index = np.arange(len(data['Issue']))
plt.bar(index, data['Approve'], bar_width, color=approve_color, label='Approve')
plt.bar(index + bar_width, data['Disapprove'], bar_width, color=disapprove_color, label='Disapprove')
plt.xlabel('Issue')
plt.ylabel('Rating')
plt.title('Obama Approval and Disapproval Ratings by Issue')
plt.xticks(index + bar_width / 2, data['Issue'], rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# Stacked Bar Chart
plt.figure(figsize=(10, 6))
plt.bar(data['Issue'], data['Approve'], color=approve_color, label='Approve')
plt.bar(data['Issue'], data['Disapprove'], bottom=data['Approve'], color=disapprove_color, label='Disapprove')
plt.xlabel('Issue')
plt.ylabel('Rating')
plt.title('Obama Approval and Disapproval Ratings by Issue')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# Pie Chart
plt.figure(figsize=(8, 8))
colors = [approve_color, disapprove_color, 'gray']
plt.pie(data['Approve'], labels=data['Issue'], autopct='%1.1f%%', colors=colors)
plt.title('Obama Approval Ratings by Issue')
plt.tight_layout()
plt.show()

# Donut Chart
plt.figure(figsize=(8, 8))
plt.pie(data['Approve'], labels=data['Issue'], autopct='%1.1f%%', colors=colors, wedgeprops=dict(width=0.4))
plt.title('Obama Approval Ratings by Issue')
plt.tight_layout()
plt.show()

# Line Chart
plt.figure(figsize=(10, 6))
plt.plot(data['Issue'], data['Approve'], marker='o', color=approve_color, label='Approve')
plt.plot(data['Issue'], data['Disapprove'], marker='o', color=disapprove_color, label='Disapprove')
plt.xlabel('Issue')
plt.ylabel('Approval/Disapproval Rating')
plt.title('Obama Approval and Disapproval Ratings by Issue')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
